# %%
from glob import glob
import librosa
import matplotlib.pyplot as plt

species = glob('/mnt/md0/birdsong-recognition/train_audio/*')
# train_audio contains many subdirectories, one for each bird species
species[0]
# Out:
# /home/jhaase/.local/lib/python3.6/site-packages/numba/core/errors.py:149: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)
# '/mnt/md0/birdsong-recognition/train_audio/aldfly'

# %%
barnswallows = glob('/mnt/md0/birdsong-recognition/train_audio/barswa/*')

# this is a path to a single mp3 sound file
barnswallows[0]
# Out:
# '/mnt/md0/birdsong-recognition/train_audio/barswa/XC134349.mp3'

# %%
import librosa.display

x, sr= librosa.load(barnswallows[0])   
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)
# Out:
# /home/jhaase/.local/lib/python3.6/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
import IPython.display as ipd
ipd.Audio('/mnt/md0/birdsong-recognition/train_audio/barswa/XC46803.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
