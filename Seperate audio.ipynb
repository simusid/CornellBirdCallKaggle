# %%
    # ! pip install pydub
    # ! pip install simpleaudio
    # ! pip install ffmpeg

# %%
cd Birdsong
# Out:
# /home/jhaase/Birdsong

# %%
ls
# Out:
# 'Load and play a birdsong.ipynb'  'visualization .ipynb'   XC2628.mp3
# 'Partial challenge.ipynb'          XC135460.mp3            XC2628.wav
# 'visualization -Copy1.ipynb'       XC135460.mp3.wav

# %%
import simpleaudio as sa
import pydub as pydub
import numpy as np

# %%
from pydub import AudioSegment
from pydub.playback import play

# %%
from __future__ import print_function
import librosa
# Out:
# /home/jhaase/.local/lib/python3.6/site-packages/numba/core/errors.py:149: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)

# %%
from glob import glob

# %%
species = glob('/mnt/md0/birdsong-recognition/train_audio/*')

# %%
type(species)
# Out:
# list

# %%
barnswallows = glob('/mnt/md0/birdsong-recognition/train_audio/barswa/*')

# %%
type(barnswallows)
# Out:
# list

# %%
barnswallows[3: 6]
# Out:
# ['/mnt/md0/birdsong-recognition/train_audio/barswa/XC142466.mp3',
#  '/mnt/md0/birdsong-recognition/train_audio/barswa/XC142632.mp3',
#  '/mnt/md0/birdsong-recognition/train_audio/barswa/XC142731.mp3']

# %%
barn_play = barnswallows[2]

# %%
sound = AudioSegment.from_mp3("XC135460.mp3")
sound.export("XC135460.wav", format="wav")
# Out:
# <_io.BufferedRandom name='XC135460.wav'>

# %%
ls
# Out:
# 'Load and play a birdsong.ipynb'  'visualization .ipynb'   XC2628.mp3
# 'Partial challenge.ipynb'          XC135460.mp3            XC2628.wav
# 'visualization -Copy1.ipynb'       XC135460.wav

# %%
song = AudioSegment.from_wav("XC2628.wav")

# %%
song
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
print(song. __dict__)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
wave_obj = sa.WaveObject(song, 2, 2, 44100)

# %%
wave_obj = sa.WaveObject.from_wave_file("XC2628.wav")

# %%
type(wave_obj)
# Out:
# simpleaudio.shiny.WaveObject

# %%
simpleaudio.PlayObject
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-3110ad9c4861> in <module>
# ----> 1 simpleaudio.PlayObject
#
# NameError: name 'simpleaudio' is not defined
